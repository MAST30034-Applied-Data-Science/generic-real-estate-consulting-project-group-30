# %%
import pandas as pd
import csv
import os
import re
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import math

# %% [markdown]
# # 2016 Census and Income data cleaning and preprocessing

# %%
income_df = pd.read_csv("../data/raw/2016Census_G02_VIC_SA2.csv")
income_df
# Out:
#      SA2_MAINCODE_2016  Median_age_persons  Median_mortgage_repay_monthly  \
# 0            201011001                  34                           1615
# 1            201011002                  42                           1500
# 2            201011003                  39                           1347
# 3            201011004                  36                           1257
# 4            201011005                  38                           1580
# ..                 ...                 ...                            ...
# 459          217041478                  44                           1400
# 460          217041479                  39                           1500
# 461          217041480                  43                           1364
# 462          297979799                  49                              0
# 463          299999499                  34                              0
#
#      Median_tot_prsnl_inc_weekly  Median_rent_weekly  \
# 0                            702                 310
# 1                            670                 260
# 2                            615                 250
# 3                            528                 240
# 4                            638                 300
# ..                           ...                 ...
# 459                          617                 223
# 460                          625                 250
# 461                          610                 250
# 462                         3000                   0
# 463                          398                   0
#
#      Median_tot_fam_inc_weekly  Average_num_psns_per_bedroom  \
# 0                         1833                           0.8
# 1                         1867                           0.8
# 2                         1574                           0.8
# 3                         1242                           0.8
# 4                         1921                           0.8
# ..                         ...                           ...
# 459                       1470                           0.8
# 460                       1510                           0.8
# 461                       1498                           0.8
# 462                          0                           0.0
# 463                          0                           0.0
#
#      Median_tot_hhd_inc_weekly  Average_household_size
# 0                         1585                     2.8
# 1                         1327                     2.3
# 2                         1198                     2.3
# 3                          945                     2.2
# 4                         1634                     2.8
# ..                         ...                     ...
# 459                       1217                     2.5
# 460                       1210                     2.5
# 461                       1144                     2.3
# 462                          0                     0.0
# 463                          0                     0.0
#
# [464 rows x 9 columns]

# %%
income_df = income_df[['SA2_MAINCODE_2016','Median_tot_prsnl_inc_weekly','Median_rent_weekly', 
                       'Median_tot_fam_inc_weekly', 'Median_tot_hhd_inc_weekly' ]]

# %%
pop_dfA = pd.read_csv("../data/raw/2016Census_G17A_VIC_SA2.csv")
pop_dfB = pd.read_csv("../data/raw/2016Census_G17B_VIC_SA2.csv")

# %%
pop_dfA = pop_dfA[['SA2_MAINCODE_2016','M_Tot_Tot', 'M_PI_NS_ns_Tot']]
pop_dfB = pop_dfB[['SA2_MAINCODE_2016','F_Tot_Tot', 'F_PI_NS_ns_Tot']]
from functools import reduce
dfs = [pop_dfA, pop_dfB]
population_df = reduce(lambda left,right: pd.merge(left,right,on='SA2_MAINCODE_2016'), dfs)

# %%
population_df['total_population'] = population_df['M_Tot_Tot']+population_df['M_PI_NS_ns_Tot']+ population_df['F_Tot_Tot']+population_df['F_PI_NS_ns_Tot']

# %%
population_df=population_df.drop(columns=['M_Tot_Tot', 'M_PI_NS_ns_Tot' ,'F_Tot_Tot', 'F_PI_NS_ns_Tot'])
population_df
# Out:
#      SA2_MAINCODE_2016  total_population
# 0            201011001              9485
# 1            201011002             10922
# 2            201011003             20423
# 3            201011004             21811
# 4            201011005              6125
# ..                 ...               ...
# 459          217041478              8373
# 460          217041479             18457
# 461          217041480             12104
# 462          297979799                37
# 463          299999499              8108
#
# [464 rows x 2 columns]

# %%
df = pd.merge(income_df, population_df, on='SA2_MAINCODE_2016', how="inner")

# %%
df
# Out:
#      SA2_MAINCODE_2016  Median_tot_prsnl_inc_weekly  Median_rent_weekly  \
# 0            201011001                          702                 310
# 1            201011002                          670                 260
# 2            201011003                          615                 250
# 3            201011004                          528                 240
# 4            201011005                          638                 300
# ..                 ...                          ...                 ...
# 459          217041478                          617                 223
# 460          217041479                          625                 250
# 461          217041480                          610                 250
# 462          297979799                         3000                   0
# 463          299999499                          398                   0
#
#      Median_tot_fam_inc_weekly  Median_tot_hhd_inc_weekly  total_population
# 0                         1833                       1585              9485
# 1                         1867                       1327             10922
# 2                         1574                       1198             20423
# 3                         1242                        945             21811
# 4                         1921                       1634              6125
# ..                         ...                        ...               ...
# 459                       1470                       1217              8373
# 460                       1510                       1210             18457
# 461                       1498                       1144             12104
# 462                          0                          0                37
# 463                          0                          0              8108
#
# [464 rows x 6 columns]

# %%
df[[ 'Median_tot_prsnl_inc_weekly','Median_rent_weekly','Median_tot_fam_inc_weekly','Median_tot_hhd_inc_weekly',
    'total_population']].describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#       Median_tot_prsnl_inc_weekly Median_rent_weekly  \
# count                   464.00000          464.00000
# mean                    660.15302          304.36422
# std                     209.39593           95.64973
# min                       0.00000            0.00000
# 25%                     547.00000          250.00000
# 50%                     634.00000          321.00000
# 75%                     731.25000          369.25000
# max                    3000.00000          540.00000
#
#       Median_tot_fam_inc_weekly Median_tot_hhd_inc_weekly total_population
# count                 464.00000                 464.00000        464.00000
# mean                 1710.42888                1431.33836      11355.34267
# std                   523.15972                 420.31686       6033.71808
# min                     0.00000                   0.00000          0.00000
# 25%                  1361.75000                1127.50000       6766.00000
# 50%                  1655.50000                1411.50000      10672.00000
# 75%                  2016.50000                1723.00000      15651.25000
# max                  3351.00000                2438.00000      40745.00000

# %% [markdown]
# # Removing zero and neg values

# %%
df = df[(df['Median_tot_prsnl_inc_weekly'] > 0) & (df['Median_rent_weekly'] > 0)&
        (df['Median_tot_fam_inc_weekly'] > 0) &
        (df['Median_tot_hhd_inc_weekly'] > 0)& (df['total_population'] > 0)]

# %%
df
# Out:
#      SA2_MAINCODE_2016  Median_tot_prsnl_inc_weekly  Median_rent_weekly  \
# 0            201011001                          702                 310
# 1            201011002                          670                 260
# 2            201011003                          615                 250
# 3            201011004                          528                 240
# 4            201011005                          638                 300
# ..                 ...                          ...                 ...
# 457          217031476                          554                 245
# 458          217041477                          613                 150
# 459          217041478                          617                 223
# 460          217041479                          625                 250
# 461          217041480                          610                 250
#
#      Median_tot_fam_inc_weekly  Median_tot_hhd_inc_weekly  total_population
# 0                         1833                       1585              9485
# 1                         1867                       1327             10922
# 2                         1574                       1198             20423
# 3                         1242                        945             21811
# 4                         1921                       1634              6125
# ..                         ...                        ...               ...
# 457                       1205                        936              3334
# 458                       1482                       1210              5759
# 459                       1470                       1217              8373
# 460                       1510                       1210             18457
# 461                       1498                       1144             12104
#
# [453 rows x 6 columns]

# %%
df[[ 'Median_tot_prsnl_inc_weekly','Median_rent_weekly','Median_tot_fam_inc_weekly','Median_tot_hhd_inc_weekly',
    'total_population']].describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#       Median_tot_prsnl_inc_weekly Median_rent_weekly  \
# count                   453.00000          453.00000
# mean                    658.65342          311.49007
# std                     156.47613           84.82881
# min                     338.00000           80.00000
# 25%                     549.00000          250.00000
# 50%                     636.00000          325.00000
# 75%                     730.00000          370.00000
# max                    1341.00000          540.00000
#
#       Median_tot_fam_inc_weekly Median_tot_hhd_inc_weekly total_population
# count                 453.00000                 453.00000        453.00000
# mean                 1744.79029                1450.15011      11612.42605
# std                   457.39634                 380.44682       5862.29146
# min                   843.00000                 477.00000         42.00000
# 25%                  1382.00000                1142.00000       7090.00000
# 50%                  1662.00000                1417.00000      10795.00000
# 75%                  2020.00000                1723.00000      15754.00000
# max                  3351.00000                2438.00000      40745.00000

# %% [markdown]
# # Removing outliers

# %%
df = df[(df['Median_tot_fam_inc_weekly'] > 1382 - ((2020-1382)*1.5)) &
        (df['Median_tot_fam_inc_weekly'] <= 2020 + ((2020-1382)*1.5))]

df = df[(df['Median_rent_weekly'] > 250 - ((370-250)*1.5)) & 
        (df['Median_rent_weekly'] <= 370 + ((370-250)*1.5))]

df = df[(df['Median_tot_prsnl_inc_weekly'] > 549 - ((730-549)*1.5)) &
        (df['Median_tot_prsnl_inc_weekly'] <= 730 + ((730-549)*1.5))]

# %%
df2 = df[(df['total_population'] < 1000)]
df2
# Out:
#      SA2_MAINCODE_2016  Median_tot_prsnl_inc_weekly  Median_rent_weekly  \
# 60           204011061                          458                 200
# 87           205031088                          412                 150
# 185          208031184                          900                 357
#
#      Median_tot_fam_inc_weekly  Median_tot_hhd_inc_weekly  total_population
# 60                        1291                        747               179
# 87                         843                        477               103
# 185                       2074                        900                42

# %%
df = df[(df['total_population'] > 1000 ) &
        (df['total_population'] <= 15754 +  ((15754-7090)*1.5))]

# %%
df
# Out:
#      SA2_MAINCODE_2016  Median_tot_prsnl_inc_weekly  Median_rent_weekly  \
# 0            201011001                          702                 310
# 1            201011002                          670                 260
# 2            201011003                          615                 250
# 3            201011004                          528                 240
# 4            201011005                          638                 300
# ..                 ...                          ...                 ...
# 457          217031476                          554                 245
# 458          217041477                          613                 150
# 459          217041478                          617                 223
# 460          217041479                          625                 250
# 461          217041480                          610                 250
#
#      Median_tot_fam_inc_weekly  Median_tot_hhd_inc_weekly  total_population
# 0                         1833                       1585              9485
# 1                         1867                       1327             10922
# 2                         1574                       1198             20423
# 3                         1242                        945             21811
# 4                         1921                       1634              6125
# ..                         ...                        ...               ...
# 457                       1205                        936              3334
# 458                       1482                       1210              5759
# 459                       1470                       1217              8373
# 460                       1510                       1210             18457
# 461                       1498                       1144             12104
#
# [430 rows x 6 columns]

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'SA2_MAINCODE_2016'}>,
#         <AxesSubplot:title={'center':'Median_tot_prsnl_inc_weekly'}>],
#        [<AxesSubplot:title={'center':'Median_rent_weekly'}>,
#         <AxesSubplot:title={'center':'Median_tot_fam_inc_weekly'}>],
#        [<AxesSubplot:title={'center':'Median_tot_hhd_inc_weekly'}>,
#         <AxesSubplot:title={'center':'total_population'}>]], dtype=object)

# %%
df.to_csv('../data/raw/income_and_pop_2016.csv', index=False)

# %% [markdown]
# # 2011 Census and Income data cleaning and preprocessing

# %%
income_df = pd.read_csv("../data/raw/2011Census_B02_VIC_SA2_short.csv")
income_df
# Out:
#      region_id  Median_age_persons  Median_mortgage_repay_monthly  \
# 0    201011001                  35                           1560
# 1    201011002                  40                           1400
# 2    201011003                  38                           1300
# 3    201011004                  35                           1288
# 4    201011005                  36                           1517
# ..         ...                 ...                            ...
# 430  217021431                  49                           1300
# 431  217021432                  37                           1512
# 432  217021433                  39                           1430
# 433  297979799                  45                              0
# 434  299999499                  32                              0
#
#      Median_Tot_prsnl_inc_weekly  Median_rent_weekly  \
# 0                            609                 250
# 1                            575                 230
# 2                            534                 210
# 3                            464                 200
# 4                            531                 250
# ..                           ...                 ...
# 430                          475                 195
# 431                          536                 220
# 432                          525                 220
# 433                         4833                   0
# 434                          352                   0
#
#      Median_Tot_fam_inc_weekly  Average_num_psns_per_bedroom  \
# 0                         1618                           1.1
# 1                         1573                           1.1
# 2                         1333                           1.1
# 3                         1062                           1.1
# 4                         1623                           1.1
# ..                         ...                           ...
# 430                       1039                           1.1
# 431                       1289                           1.1
# 432                       1316                           1.1
# 433                          0                           0.0
# 434                          0                           0.0
#
#      Median_Tot_hhd_inc_weekly  Average_household_size
# 0                         1405                     2.8
# 1                         1120                     2.3
# 2                         1011                     2.4
# 3                          857                     2.3
# 4                         1409                     2.8
# ..                         ...                     ...
# 430                        841                     2.2
# 431                       1047                     2.5
# 432                        998                     2.3
# 433                          0                     0.0
# 434                          0                     0.0
#
# [435 rows x 9 columns]

# %%
income_df2 = income_df[['region_id','Median_Tot_prsnl_inc_weekly','Median_rent_weekly', 
                       'Median_Tot_fam_inc_weekly', 'Median_Tot_hhd_inc_weekly' ]]

# %%
pop_dfA2 = pd.read_csv("../data/raw/2011Census_B17A_VIC_SA2_short.csv")
pop_dfB2 = pd.read_csv("../data/raw/2011Census_B17B_VIC_SA2_short.csv")

# %%
pop_dfA2 = pop_dfA2[['region_id','M_Tot_Tot', 'M_PI_NS_ns_Tot']]
pop_dfB2 = pop_dfB2[['region_id','F_Tot_Tot', 'F_PI_NS_ns_Tot']]

# %%
from functools import reduce
dfs2 = [pop_dfA2, pop_dfB2]
population_df2 = reduce(lambda left,right: pd.merge(left,right,on='region_id'), dfs2)

# %%
population_df2['total_population'] = population_df2['M_Tot_Tot']+population_df2['M_PI_NS_ns_Tot']+ population_df2['F_Tot_Tot']+population_df2['F_PI_NS_ns_Tot']

# %%
population_df2=population_df2.drop(columns=['M_Tot_Tot', 'M_PI_NS_ns_Tot' ,'F_Tot_Tot', 'F_PI_NS_ns_Tot'])
population_df2
# Out:
#      region_id  total_population
# 0    201011001              6690
# 1    201011002             10792
# 2    201011003             19036
# 3    201011004             20180
# 4    201011005              5537
# ..         ...               ...
# 430  217021431              3075
# 431  217021432             16456
# 432  217021433             11473
# 433  297979799                44
# 434  299999499              8151
#
# [435 rows x 2 columns]

# %%
df_2011 = pd.merge(income_df2, population_df2, on='region_id', how="inner")

# %%
df_2011[[ 'Median_Tot_prsnl_inc_weekly','Median_rent_weekly','Median_Tot_fam_inc_weekly','Median_Tot_hhd_inc_weekly',
    'total_population']].describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#       Median_Tot_prsnl_inc_weekly Median_rent_weekly  \
# count                   435.00000          435.00000
# mean                    580.47356          255.78851
# std                     267.60913           90.70536
# min                       0.00000            0.00000
# 25%                     468.50000          195.00000
# 50%                     548.00000          270.00000
# 75%                     647.00000          321.00000
# max                    4833.00000          508.00000
#
#       Median_Tot_fam_inc_weekly Median_Tot_hhd_inc_weekly total_population
# count                 435.00000                 435.00000        435.00000
# mean                 1486.28736                1216.40000      10781.34943
# std                   509.67290                 390.12731       6008.40140
# min                     0.00000                   0.00000          0.00000
# 25%                  1142.50000                 931.00000       6205.50000
# 50%                  1426.00000                1204.00000       9765.00000
# 75%                  1747.00000                1452.50000      14893.50000
# max                  5000.00000                2304.00000      29834.00000

# %% [markdown]
# # Removing zero and neg values

# %%
df_2011 = df_2011[(df_2011['Median_Tot_prsnl_inc_weekly'] > 0) & (df_2011['Median_rent_weekly'] > 0)&
        (df_2011['Median_Tot_fam_inc_weekly'] > 0) &
        (df_2011['Median_Tot_hhd_inc_weekly'] > 0)& (df_2011['total_population'] > 0)]

# %% [markdown]
# # Removing outliers

# %%
df_2011[[ 'Median_Tot_prsnl_inc_weekly','Median_rent_weekly','Median_Tot_fam_inc_weekly','Median_Tot_hhd_inc_weekly',
    'total_population']].describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#       Median_Tot_prsnl_inc_weekly Median_rent_weekly  \
# count                   423.00000          423.00000
# mean                    574.07329          263.04492
# std                     144.43507           80.92054
# min                     312.00000           52.00000
# 25%                     473.50000          200.00000
# 50%                     553.00000          275.00000
# 75%                     644.50000          321.00000
# max                    1170.00000          508.00000
#
#       Median_Tot_fam_inc_weekly Median_Tot_hhd_inc_weekly total_population
# count                 423.00000                 423.00000        423.00000
# mean                 1507.60284                1246.41844      11067.09693
# std                   437.98663                 348.56062       5832.43679
# min                   675.00000                 589.00000         10.00000
# 25%                  1163.00000                 955.50000       6311.50000
# 50%                  1433.00000                1228.00000      10031.00000
# 75%                  1748.50000                1456.50000      15023.00000
# max                  2746.00000                2304.00000      29834.00000

# %%
#areas with less than 1000 population

df_low_Pop = df[(df['total_population'] < 1000)]
len(df_low_Pop)
# Out:
# 0

# %%
df_2011 = df_2011[(df_2011['Median_Tot_fam_inc_weekly'] > 1163 - ((1748.50-1163)*1.5)) &
        (df_2011['Median_Tot_fam_inc_weekly'] <= 1748.50 + ((1748.50-1163)*1.5))]

df_2011 = df_2011[(df_2011['Median_rent_weekly'] > 200 - ((321-200)*1.5)) & 
        (df_2011['Median_rent_weekly'] <= 321 + ((321-200)*1.5))]

df_2011 = df_2011[(df_2011['Median_Tot_prsnl_inc_weekly'] > 473.5 - ((644.5-473.5)*1.5)) &
        (df_2011['Median_Tot_prsnl_inc_weekly'] <= 644.5 + ((644.5-473.5)*1.5))]

# %%
df_2011 = df_2011[(df_2011['total_population'] > 1000 ) &
        (df_2011['total_population'] <= 15023 +  ((15023-6311)*1.5))]

# %%
df_2011.hist()
# Out:
# array([[<AxesSubplot:title={'center':'region_id'}>,
#         <AxesSubplot:title={'center':'Median_Tot_prsnl_inc_weekly'}>],
#        [<AxesSubplot:title={'center':'Median_rent_weekly'}>,
#         <AxesSubplot:title={'center':'Median_Tot_fam_inc_weekly'}>],
#        [<AxesSubplot:title={'center':'Median_Tot_hhd_inc_weekly'}>,
#         <AxesSubplot:title={'center':'total_population'}>]], dtype=object)

# %%
df_2011.to_csv('../data/raw/income_and_pop_2011.csv', index=False)
