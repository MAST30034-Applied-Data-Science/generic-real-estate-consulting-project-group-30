# %%
import pandas as pd
import numpy as np

df = pd.read_json('../data/raw/full_property.json')

# %%
# take a look at the size of the data
df.shape
# Out:
# (12, 11206)

# %%
# there are 12 rows in the data, but we have 12 features,
# so data needs to have 12 columns instead -- need to transpose this data

df = df.transpose()
df.head()
# Out:
#                                                                                              name  \
# https://www.domain.com.au/unit-503-466-swanston...  unit 503/466 Swanston Street Carlton VIC 3053
# https://www.domain.com.au/61-rowans-road-highet...                61 Rowans Road Highett VIC 3190
# https://www.domain.com.au/29-caspian-circuit-po...         29 Caspian Circuit Point Cook VIC 3030
# https://www.domain.com.au/36-bradleys-lane-nort...     36 Bradleys Lane North Warrandyte VIC 3113
# https://www.domain.com.au/12-isaac-road-keysbor...             12 Isaac Road Keysborough VIC 3173
#
#                                                            cost_text  \
# https://www.domain.com.au/unit-503-466-swanston...              $320
# https://www.domain.com.au/61-rowans-road-highet...           $460.00
# https://www.domain.com.au/29-caspian-circuit-po...  $430.00 per week
# https://www.domain.com.au/36-bradleys-lane-nort...     $720 per week
# https://www.domain.com.au/12-isaac-road-keysbor...           $515 pw
#
#                                                                    coordinates  \
# https://www.domain.com.au/unit-503-466-swanston...  [-37.8059838, 144.9632701]
# https://www.domain.com.au/61-rowans-road-highet...  [-37.9475765, 145.0509956]
# https://www.domain.com.au/29-caspian-circuit-po...  [-37.9002294, 144.7452156]
# https://www.domain.com.au/36-bradleys-lane-nort...  [-37.7370336, 145.2124356]
# https://www.domain.com.au/12-isaac-road-keysbor...  [-37.9840266, 145.1782469]
#
#                                                    Bed Bath Park  \
# https://www.domain.com.au/unit-503-466-swanston...   1    1    0
# https://www.domain.com.au/61-rowans-road-highet...   3    1    1
# https://www.domain.com.au/29-caspian-circuit-po...   3    2    2
# https://www.domain.com.au/36-bradleys-lane-nort...   4    3    3
# https://www.domain.com.au/12-isaac-road-keysbor...   3    3    1
#
#                                                               property_type  \
# https://www.domain.com.au/unit-503-466-swanston...  Apartment / Unit / Flat
# https://www.domain.com.au/61-rowans-road-highet...                    House
# https://www.domain.com.au/29-caspian-circuit-po...                    House
# https://www.domain.com.au/36-bradleys-lane-nort...                    House
# https://www.domain.com.au/12-isaac-road-keysbor...                    House
#
#                                                                                        desc_head  \
# https://www.domain.com.au/unit-503-466-swanston...  Fully Furnished Studio Apartment in Swanston
# https://www.domain.com.au/61-rowans-road-highet...     Quaint three bedroom in a great location!
# https://www.domain.com.au/29-caspian-circuit-po...                       Life at Your Fingertips
# https://www.domain.com.au/36-bradleys-lane-nort...                                 Bradleys Lane
# https://www.domain.com.au/12-isaac-road-keysbor...                        LUXURY SUBURBAN LIVING
#
#                                                                                                  desc  \
# https://www.domain.com.au/unit-503-466-swanston...   class="css-dxogle">* Unverified feature<svg a...
# https://www.domain.com.au/61-rowans-road-highet...   class="css-dxogle">* Unverified feature<svg a...
# https://www.domain.com.au/29-caspian-circuit-po...   class="css-dxogle">* Unverified feature<svg a...
# https://www.domain.com.au/36-bradleys-lane-nort...   class="css-dxogle">* Unverified feature<svg a...
# https://www.domain.com.au/12-isaac-road-keysbor...   class="css-dxogle">* Unverified feature<svg a...
#
#                                                                                   additional features  \
# https://www.domain.com.au/unit-503-466-swanston...       [Alarm System, Built in wardrobes, Intercom]
# https://www.domain.com.au/61-rowans-road-highet...  [Split System Air Con, Split System Heating, E...
# https://www.domain.com.au/29-caspian-circuit-po...                                                 []
# https://www.domain.com.au/36-bradleys-lane-nort...                                                 []
# https://www.domain.com.au/12-isaac-road-keysbor...                   [Built in wardrobes, Dishwasher]
#
#                                                    internal_area_sqkm  \
# https://www.domain.com.au/unit-503-466-swanston...                 []
# https://www.domain.com.au/61-rowans-road-highet...                NaN
# https://www.domain.com.au/29-caspian-circuit-po...                NaN
# https://www.domain.com.au/36-bradleys-lane-nort...                NaN
# https://www.domain.com.au/12-isaac-road-keysbor...                NaN
#
#                                                    land_area_sqkm
# https://www.domain.com.au/unit-503-466-swanston...             []
# https://www.domain.com.au/61-rowans-road-highet...             []
# https://www.domain.com.au/29-caspian-circuit-po...             []
# https://www.domain.com.au/36-bradleys-lane-nort...             []
# https://www.domain.com.au/12-isaac-road-keysbor...             []

# %%
type(df["coordinates"][0])
# Out:
# list

# %% [markdown]
# ### 1: Cost

# %%
# the cost of a real estate property is in dollars per week.
# I will transform all the values in the cost_text column into integers.

df2 = df.copy()
import re


# the list of instances where the values are ambiguous or invalid,
# each instance will be in the form of (index, string)
ambiguous = dict()

for i in range(df2.shape[0]):
    cost = re.findall(r"[\d,]+", df2.iat[i, 1])

    if len(cost) == 0:
        df2.iat[i, 1] = np.nan
    
    else:
        # find the element with length 3, since it's the most likely one
        cost2 = [i for i in cost if len(i) == 3]

        if len(cost2) == 1:
            # if there's only one, then it's very likely that it's the correct price we want
            df2.iat[i, 1] = int(cost2[0])

        else:
            # otherwise, this is where things get wacky
            string = df2.iat[i, 1]
        
            # if there is no mention, assume the price is per week
            # there will be outliers, but they can be detected and removed afterwards.

            # if only monthly or yearly price is listed, simply get the estimate by dividing 4 or 52.
            week = ["/w", "pw", "PW", "Week", "week"]
            month = ["pcm", "PCM", "pm", "PM", "mth", "month", "Month", "MONTH"]
            annual = ["p.a", "pa", "Annually"]

            # none of month or annual price is listed, so the listed price is likely to be per week
            if not any(sub_month in string for sub_month in month) and \
                not any(sub_annual in string for sub_annual in annual):
                # dealing with N,NNN.NN format
                if len(cost) == 1:
                    df2.iat[i, 1] = int(cost[0].replace(",", ""))
                elif len(cost) == 2 and len(cost[1]) == 2:
                    df2.iat[i, 1] = int(cost[0].replace(",", "")) + float(f"0.{cost[1]}")
                else:
                    # the only other alternative to this is to clean it manually.
                    # However, we actually end up with 59 values left *in total*,
                    # and doing so manually is going to be extremely tedious. Therefore, I opt
                    # to sacrifice the tedious-ness with a slightly higher chance of picking
                    # up false positives (i.e., picking up values that shouldn't be picked up)
                    # by taking cost[0] as the true rent price.
                    df2.iat[i, 1] = int(cost[0].replace(",", ""))

                    # you can see the cost_text string by looking at this dict value
                    ambiguous[i] = string

            # weekly price is listed
            elif any(sub_week in string for sub_week in week):
                # dealing with N,NNN.NN format
                if len(cost) == 1:
                    df2.iat[i, 1] = int(cost[0].replace(",", ""))
                elif len(cost) == 2 and len(cost[1]) == 2:
                    df2.iat[i, 1] = int(cost[0].replace(",", "")) + float(f"0.{cost[1]}")
                else:
                    df2.iat[i, 1] = int(cost[0].replace(",", ""))
                    ambiguous[i] = string

            # only monthly price is listed
            elif any(sub_month in string for sub_month in month) and \
                not any(sub_week in string for sub_week in week) and \
                not any(sub_annual in string for sub_annual in annual):
                if len(cost) == 1:
                    df2.iat[i, 1] = int(cost[0].replace(",", "")) / 4
                elif len(cost) == 2 and len(cost[1]) == 2:
                    df2.iat[i, 1] = (int(cost[0].replace(",", "")) + float(f"0.{cost[1]}")) / 4
                else:
                    df2.iat[i, 1] = int(cost[0].replace(",", ""))
                    ambiguous[i] = string

            # only annual price price is listed
            elif not any(sub_month in string for sub_month in month) and \
                not any(sub_week in string for sub_week in week) and \
                any(sub_annual in string for sub_annual in annual):
                if len(cost) == 1:
                    df2.iat[i, 1] = int(cost[0].replace(",", "")) / 52
                elif len(cost) == 2 and len(cost[1]) == 2:
                    df2.iat[i, 1] = (int(cost[0].replace(",", "")) + float(f"0.{cost[1]}")) / 52
                else:
                    df2.iat[i, 1] = int(cost[0].replace(",", ""))
                    ambiguous[i] = string

            else:
                df2.iat[i, 1] = int(cost[0].replace(",", ""))
                ambiguous[i] = string

ambiguous
# Out:
# {954: '$1099pw - Stay 1 mth+',
#  1045: '$1190pw Stay 1 mth',
#  1166: '$1050pw Stay 1 mth',
#  1723: '$1100 PW / $4780 PCM',
#  1975: '$1029pw - Stay 1 mth+',
#  2093: '$325 Per Week Until April 2022. Increase to $335 Per Week a',
#  2293: '$220.00 pw- (rent increase to $285 pw from 25/1/23',
#  2414: '$195 per week - Then $245 per week from 10/02/2023',
#  2544: 'APPLY NOW - Studio From $250/w & 2 Bed From $385/w',
#  2554: '$3,000 per month, plus GST & Outgoings',
#  2751: '$560pw/$2.433pcm',
#  2758: '$185 Per Week - $195pw from 03/02/2023',
#  2868: '$240 pw until 20/01/2023 then increase to $320pw',
#  3178: '$1036pw - Stay 1 mth+',
#  3357: '$750 per week 750',
#  3425: '$1015pw - Stay 1 mth+',
#  3478: '$950pw/$4.128pcm',
#  3817: '$480 per week 480.00',
#  3845: '$750 to $775',
#  4087: '$260 to $280',
#  4137: '$2300pw / $9994pcm',
#  4207: 'From $155 - $285 pw (bills included)',
#  5045: '$1246pw - Stay 1 mth+',
#  5460: '($1,350 pcm + $2,150 pcm)',
#  5826: '$1800pw / $7821pcm',
#  6079: '$1200pw - Stay 1 mth+',
#  6090: '$160pw / $695pcm',
#  6206: '$800 to $880',
#  6287: '$170 to $240',
#  6366: '$1218pw - Stay 1 mth+',
#  6529: '$1300pw/ $5649pcm',
#  6654: '$200pw / $869',
#  6747: '$1250 pw / $5431 pcm',
#  6799: '$1100 pw - $4780 pcm',
#  6823: '$1150 PW / $6900 PCM',
#  6886: '$450 pw $480 pw',
#  6939: '$550 Per Week Until 31 Jan 2023, After $600 per week',
#  6962: '$1155pw - Stay 1 mth+',
#  7309: 'LEASED - MORE PROPERTIES WANTED CALL ANDREW 0407 060 344',
#  7783: '$590 pw - First 6 months $390 pw',
#  8067: '$1,150pw/$4,997pcm',
#  8081: '$1,580pw/$6,865pcm',
#  8358: '$700-$750/PW',
#  8414: '$230pw / $999pcm',
#  8691: '$420 to $450',
#  8777: '$1043pw - Stay 1 mth+',
#  8891: '$1200pw - Stay 1 mth+',
#  9133: '$800 to $880',
#  9433: '$1085pw - Stay 1 mth+',
#  9571: '$1,150PW/$4,997PCM',
#  9593: '$1400pw/$6083pcm',
#  9687: '$235pw Single $285pw Couple',
#  9947: '$180.00 to $220.00',
#  10484: '$1085pw - Stay 1 mth+',
#  10631: 'Priced From $220pw / $956 pcm',
#  10815: '$160pw / $695pcm',
#  10936: '$1015pw - Stay 1 mth+',
#  11010: '$1015pw - Stay 1 mth+',
#  11131: '$1200pw/$5214pcm'}

# %%
### OUTLIER DETECTION/REMOVAL
import matplotlib.pyplot as plt

df = df2.copy()

df = df.dropna(subset=["cost_text"])
df = df.sort_values(by=["cost_text"])
df.head(8)
# Out:
#                                                                                               name  \
# https://www.domain.com.au/18-any-street-elwood-...                   18 ANY Street Elwood VIC 3184
# https://www.domain.com.au/epping-vic-3076-14979037                                 Epping VIC 3076
# https://www.domain.com.au/1102-70-lorimer-stree...       1102/70 Lorimer Street Docklands VIC 3008
# https://www.domain.com.au/hayston-views-epping-...                   Hayston Views Epping VIC 3076
# https://www.domain.com.au/point-cook-vic-3030-1...                             Point Cook VIC 3030
# https://www.domain.com.au/32-st-edmonds-rd-prah...               32 St Edmonds Rd Prahran VIC 3181
# https://www.domain.com.au/cp831-888-collins-str...     CP831/888 Collins Street Docklands VIC 3008
# https://www.domain.com.au/cp1507-442-elizabeth-...  CP1507/442 Elizabeth Street Melbourne VIC 3000
#
#                                                    cost_text  \
# https://www.domain.com.au/18-any-street-elwood-...       1.0
# https://www.domain.com.au/epping-vic-3076-14979037         2
# https://www.domain.com.au/1102-70-lorimer-stree...         2
# https://www.domain.com.au/hayston-views-epping-...         2
# https://www.domain.com.au/point-cook-vic-3030-1...         2
# https://www.domain.com.au/32-st-edmonds-rd-prah...        40
# https://www.domain.com.au/cp831-888-collins-str...        50
# https://www.domain.com.au/cp1507-442-elizabeth-...        50
#
#                                                                    coordinates  \
# https://www.domain.com.au/18-any-street-elwood-...  [-37.8837091, 144.9896471]
# https://www.domain.com.au/epping-vic-3076-14979037   [-37.6341341, 145.016269]
# https://www.domain.com.au/1102-70-lorimer-stree...    [-37.824812, 144.945973]
# https://www.domain.com.au/hayston-views-epping-...  [-37.6290575, 145.0330526]
# https://www.domain.com.au/point-cook-vic-3030-1...  [-37.9086372, 144.7522315]
# https://www.domain.com.au/32-st-edmonds-rd-prah...  [-37.8501194, 144.9920021]
# https://www.domain.com.au/cp831-888-collins-str...  [-37.8207394, 144.9480769]
# https://www.domain.com.au/cp1507-442-elizabeth-...  [-37.8090217, 144.9608512]
#
#                                                    Bed Bath Park  \
# https://www.domain.com.au/18-any-street-elwood-...   2    1    1
# https://www.domain.com.au/epping-vic-3076-14979037   4    2    2
# https://www.domain.com.au/1102-70-lorimer-stree...   2    2    2
# https://www.domain.com.au/hayston-views-epping-...   4    2    2
# https://www.domain.com.au/point-cook-vic-3030-1...   4    2    2
# https://www.domain.com.au/32-st-edmonds-rd-prah...   1    1    0
# https://www.domain.com.au/cp831-888-collins-str...   2    1    1
# https://www.domain.com.au/cp1507-442-elizabeth-...   0    1    0
#
#                                                                     property_type  \
# https://www.domain.com.au/18-any-street-elwood-...  New Apartments / Off the Plan
# https://www.domain.com.au/epping-vic-3076-14979037                          House
# https://www.domain.com.au/1102-70-lorimer-stree...        Apartment / Unit / Flat
# https://www.domain.com.au/hayston-views-epping-...                          House
# https://www.domain.com.au/point-cook-vic-3030-1...                          House
# https://www.domain.com.au/32-st-edmonds-rd-prah...        Apartment / Unit / Flat
# https://www.domain.com.au/cp831-888-collins-str...        Apartment / Unit / Flat
# https://www.domain.com.au/cp1507-442-elizabeth-...        Apartment / Unit / Flat
#
#                                                                                             desc_head  \
# https://www.domain.com.au/18-any-street-elwood-...                           *** LANDLORDS WANTED ***
# https://www.domain.com.au/epping-vic-3076-14979037                    No Deposit Required or Rent2own
# https://www.domain.com.au/1102-70-lorimer-stree...            Hidden Gem in the heart of Yarra's Edge
# https://www.domain.com.au/hayston-views-epping-...  Rent2own Program - Home Will Be built To Satis...
# https://www.domain.com.au/point-cook-vic-3030-1...                           Rent2own with No Deposit
# https://www.domain.com.au/32-st-edmonds-rd-prah...  1x Secured Off Street Undercover Car Park avai...
# https://www.domain.com.au/cp831-888-collins-str...  888 Collins Street, Docklands, VIC 3008- Car S...
# https://www.domain.com.au/cp1507-442-elizabeth-...  442 Elizabeth Street, Melbourne, VIC 3000 - Ca...
#
#                                                                                                  desc  \
# https://www.domain.com.au/18-any-street-elwood-...  Do you own a property that you are currently l...
# https://www.domain.com.au/epping-vic-3076-14979037   class="css-dxogle">* Unverified feature<svg a...
# https://www.domain.com.au/1102-70-lorimer-stree...  Welcome to 'Tower 3' in Mirvac's prestigious Y...
# https://www.domain.com.au/hayston-views-epping-...  Rent2own Building Grant Extended until March 2...
# https://www.domain.com.au/point-cook-vic-3030-1...  First Step Homes has a solution for Homeowners...
# https://www.domain.com.au/32-st-edmonds-rd-prah...             PROPERTY ID: 7906 (quote when calling)
# https://www.domain.com.au/cp831-888-collins-str...  . Secure indoor car space available for rent i...
# https://www.domain.com.au/cp1507-442-elizabeth-...  . Secure indoor car space available for rent i...
#
#                                                                                   additional features  \
# https://www.domain.com.au/18-any-street-elwood-...                                                 []
# https://www.domain.com.au/epping-vic-3076-14979037  [Air conditioning, Bath, Built in wardrobes, M...
# https://www.domain.com.au/1102-70-lorimer-stree...  [Ensuite, Dishwasher, Built in wardrobes, Gym,...
# https://www.domain.com.au/hayston-views-epping-...  [Air conditioning, Ensuite, Built in wardrobes...
# https://www.domain.com.au/point-cook-vic-3030-1...  [Air conditioning, Bath, Built in wardrobes, M...
# https://www.domain.com.au/32-st-edmonds-rd-prah...                [Secure Parking, Rentbetter.com.au]
# https://www.domain.com.au/cp831-888-collins-str...                                   [Secure Parking]
# https://www.domain.com.au/cp1507-442-elizabeth-...                                                 []
#
#                                                    internal_area_sqkm  \
# https://www.domain.com.au/18-any-street-elwood-...                 []
# https://www.domain.com.au/epping-vic-3076-14979037                NaN
# https://www.domain.com.au/1102-70-lorimer-stree...                 []
# https://www.domain.com.au/hayston-views-epping-...              [190]
# https://www.domain.com.au/point-cook-vic-3030-1...                NaN
# https://www.domain.com.au/32-st-edmonds-rd-prah...                 []
# https://www.domain.com.au/cp831-888-collins-str...                 []
# https://www.domain.com.au/cp1507-442-elizabeth-...                 []
#
#                                                    land_area_sqkm
# https://www.domain.com.au/18-any-street-elwood-...             []
# https://www.domain.com.au/epping-vic-3076-14979037             []
# https://www.domain.com.au/1102-70-lorimer-stree...             []
# https://www.domain.com.au/hayston-views-epping-...          [552]
# https://www.domain.com.au/point-cook-vic-3030-1...             []
# https://www.domain.com.au/32-st-edmonds-rd-prah...             []
# https://www.domain.com.au/cp831-888-collins-str...             []
# https://www.domain.com.au/cp1507-442-elizabeth-...             []

# %%
# well this one's easy, the first 5 values are very likely to be a false positive and thus they should be removed.
df = df.drop(df.index[:5])
df
# Out:
#                                                                                                  name  \
# https://www.domain.com.au/32-st-edmonds-rd-prah...                  32 St Edmonds Rd Prahran VIC 3181
# https://www.domain.com.au/cp831-888-collins-str...        CP831/888 Collins Street Docklands VIC 3008
# https://www.domain.com.au/cp1507-442-elizabeth-...     CP1507/442 Elizabeth Street Melbourne VIC 3000
# https://www.domain.com.au/car-park-31-a-beckett...    Car Park 31 A'Beckett Street Melbourne VIC 3000
# https://www.domain.com.au/carpark-105-batman-st...  Carpark/105 Batman street West Melbourne VIC 3003
# ...                                                                                               ...
# https://www.domain.com.au/52-black-st-brighton-...                      52 Black St Brighton VIC 3186
# https://www.domain.com.au/821-glen-huntly-road-...            821 Glen Huntly Road Caulfield VIC 3162
# https://www.domain.com.au/148a-ferguson-street-...         148A Ferguson Street Williamstown VIC 3016
# https://www.domain.com.au/110-beevers-street-fo...              110 Beevers Street Footscray VIC 3011
# https://www.domain.com.au/level-3-302-13-15-lak...  Level 3, 302/13-15 Lake Street Caroline Spring...
#
#                                                    cost_text  \
# https://www.domain.com.au/32-st-edmonds-rd-prah...        40
# https://www.domain.com.au/cp831-888-collins-str...        50
# https://www.domain.com.au/cp1507-442-elizabeth-...        50
# https://www.domain.com.au/car-park-31-a-beckett...        50
# https://www.domain.com.au/carpark-105-batman-st...        50
# ...                                                      ...
# https://www.domain.com.au/52-black-st-brighton-...      5500
# https://www.domain.com.au/821-glen-huntly-road-...     38000
# https://www.domain.com.au/148a-ferguson-street-...     39000
# https://www.domain.com.au/110-beevers-street-fo...   85000.0
# https://www.domain.com.au/level-3-302-13-15-lak...   4125000
#
#                                                                           coordinates  \
# https://www.domain.com.au/32-st-edmonds-rd-prah...         [-37.8501194, 144.9920021]
# https://www.domain.com.au/cp831-888-collins-str...         [-37.8207394, 144.9480769]
# https://www.domain.com.au/cp1507-442-elizabeth-...         [-37.8090217, 144.9608512]
# https://www.domain.com.au/car-park-31-a-beckett...           [-37.809745, 144.958777]
# https://www.domain.com.au/carpark-105-batman-st...          [-37.810968, 144.9504968]
# ...                                                                               ...
# https://www.domain.com.au/52-black-st-brighton-...         [-37.9159452, 144.9989003]
# https://www.domain.com.au/821-glen-huntly-road-...          [-37.886816, 145.0229097]
# https://www.domain.com.au/148a-ferguson-street-...  [-37.85808370000001, 144.8926036]
# https://www.domain.com.au/110-beevers-street-fo...         [-37.7958415, 144.9060052]
# https://www.domain.com.au/level-3-302-13-15-lak...         [-37.7316459, 144.7446886]
#
#                                                    Bed Bath Park  \
# https://www.domain.com.au/32-st-edmonds-rd-prah...   1    1    0
# https://www.domain.com.au/cp831-888-collins-str...   2    1    1
# https://www.domain.com.au/cp1507-442-elizabeth-...   0    1    0
# https://www.domain.com.au/car-park-31-a-beckett...   2    1    0
# https://www.domain.com.au/carpark-105-batman-st...   1    1    1
# ...                                                 ..  ...  ...
# https://www.domain.com.au/52-black-st-brighton-...   3    2    1
# https://www.domain.com.au/821-glen-huntly-road-...   3    2    2
# https://www.domain.com.au/148a-ferguson-street-...   3    1    1
# https://www.domain.com.au/110-beevers-street-fo...   3    2    0
# https://www.domain.com.au/level-3-302-13-15-lak...   3    2    2
#
#                                                               property_type  \
# https://www.domain.com.au/32-st-edmonds-rd-prah...  Apartment / Unit / Flat
# https://www.domain.com.au/cp831-888-collins-str...  Apartment / Unit / Flat
# https://www.domain.com.au/cp1507-442-elizabeth-...  Apartment / Unit / Flat
# https://www.domain.com.au/car-park-31-a-beckett...                    House
# https://www.domain.com.au/carpark-105-batman-st...                    House
# ...                                                                     ...
# https://www.domain.com.au/52-black-st-brighton-...                    House
# https://www.domain.com.au/821-glen-huntly-road-...            Semi-Detached
# https://www.domain.com.au/148a-ferguson-street-...                   Studio
# https://www.domain.com.au/110-beevers-street-fo...  Apartment / Unit / Flat
# https://www.domain.com.au/level-3-302-13-15-lak...  Apartment / Unit / Flat
#
#                                                                                             desc_head  \
# https://www.domain.com.au/32-st-edmonds-rd-prah...  1x Secured Off Street Undercover Car Park avai...
# https://www.domain.com.au/cp831-888-collins-str...  888 Collins Street, Docklands, VIC 3008- Car S...
# https://www.domain.com.au/cp1507-442-elizabeth-...  442 Elizabeth Street, Melbourne, VIC 3000 - Ca...
# https://www.domain.com.au/car-park-31-a-beckett...  Car Park for rent @ 31 A'Beckett Street Melbourne
# https://www.domain.com.au/carpark-105-batman-st...  **Car Park Spaces Available For Lease @ Melbou...
# ...                                                                                               ...
# https://www.domain.com.au/52-black-st-brighton-...                      Fully Furnished  -  Brand New
# https://www.domain.com.au/821-glen-huntly-road-...  Business Opportunity Plus Residential Living I...
# https://www.domain.com.au/148a-ferguson-street-...                       OFFICE SPACE IN WILLIAMSTOWN
# https://www.domain.com.au/110-beevers-street-fo...  Purpose Built Accommodation Home **INSPECTIONS...
# https://www.domain.com.au/level-3-302-13-15-lak...                              ENDLESS POSSIBILITIES
#
#                                                                                                  desc  \
# https://www.domain.com.au/32-st-edmonds-rd-prah...             PROPERTY ID: 7906 (quote when calling)
# https://www.domain.com.au/cp831-888-collins-str...  . Secure indoor car space available for rent i...
# https://www.domain.com.au/cp1507-442-elizabeth-...  . Secure indoor car space available for rent i...
# https://www.domain.com.au/car-park-31-a-beckett...  Car park for rent close to RMIT, Melbourne cen...
# https://www.domain.com.au/carpark-105-batman-st...  ***CP 1702 (295)/393 Spencer Street, West Melb...
# ...                                                                                               ...
# https://www.domain.com.au/52-black-st-brighton-...   class="css-dxogle">* Unverified feature<svg a...
# https://www.domain.com.au/821-glen-huntly-road-...   class="css-dxogle">* Unverified feature<svg a...
# https://www.domain.com.au/148a-ferguson-street-...  Located in central Williamstown, this property...
# https://www.domain.com.au/110-beevers-street-fo...  Situated in central Footscray and within walki...
# https://www.domain.com.au/level-3-302-13-15-lak...  - Centrally located with tranquil views.\n- Le...
#
#                                                                                   additional features  \
# https://www.domain.com.au/32-st-edmonds-rd-prah...                [Secure Parking, Rentbetter.com.au]
# https://www.domain.com.au/cp831-888-collins-str...                                   [Secure Parking]
# https://www.domain.com.au/cp1507-442-elizabeth-...                                                 []
# https://www.domain.com.au/car-park-31-a-beckett...                                                 []
# https://www.domain.com.au/carpark-105-batman-st...                                                 []
# ...                                                                                               ...
# https://www.domain.com.au/52-black-st-brighton-...                                                 []
# https://www.domain.com.au/821-glen-huntly-road-...  [Air conditioning, Close to transport, Close t...
# https://www.domain.com.au/148a-ferguson-street-...                                                 []
# https://www.domain.com.au/110-beevers-street-fo...                                                 []
# https://www.domain.com.au/level-3-302-13-15-lak...  [Air conditioning, Heating, Security Access, S...
#
#                                                    internal_area_sqkm  \
# https://www.domain.com.au/32-st-edmonds-rd-prah...                 []
# https://www.domain.com.au/cp831-888-collins-str...                 []
# https://www.domain.com.au/cp1507-442-elizabeth-...                 []
# https://www.domain.com.au/car-park-31-a-beckett...                NaN
# https://www.domain.com.au/carpark-105-batman-st...                NaN
# ...                                                               ...
# https://www.domain.com.au/52-black-st-brighton-...              [294]
# https://www.domain.com.au/821-glen-huntly-road-...              [184]
# https://www.domain.com.au/148a-ferguson-street-...                NaN
# https://www.domain.com.au/110-beevers-street-fo...                 []
# https://www.domain.com.au/level-3-302-13-15-lak...                 []
#
#                                                    land_area_sqkm
# https://www.domain.com.au/32-st-edmonds-rd-prah...             []
# https://www.domain.com.au/cp831-888-collins-str...             []
# https://www.domain.com.au/cp1507-442-elizabeth-...             []
# https://www.domain.com.au/car-park-31-a-beckett...             []
# https://www.domain.com.au/carpark-105-batman-st...             []
# ...                                                           ...
# https://www.domain.com.au/52-black-st-brighton-...          [900]
# https://www.domain.com.au/821-glen-huntly-road-...             []
# https://www.domain.com.au/148a-ferguson-street-...             []
# https://www.domain.com.au/110-beevers-street-fo...             []
# https://www.domain.com.au/level-3-302-13-15-lak...             []
#
# [11008 rows x 12 columns]

# %%
# the last 4 values are also veeery unlikely or rather, almost impossible to actually happen.
df = df.sort_values(by=["cost_text"], ascending=False)
df = df.drop(df.index[:5])

# %%
# now the clear outliers are removed, let's see how the data is distributed
cost_text = df["cost_text"].to_list()
plt.boxplot(cost_text)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7eff11adb250>,
#   <matplotlib.lines.Line2D at 0x7eff11adb520>],
#  'caps': [<matplotlib.lines.Line2D at 0x7eff11adb8b0>,
#   <matplotlib.lines.Line2D at 0x7eff11adbac0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7eff11ac0f40>],
#  'medians': [<matplotlib.lines.Line2D at 0x7eff11adbd90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7eff11ae90a0>],
#  'means': []}

# %%
# as seen on the graph there, the data looks very reasonable and there is no one obvious outlier that sticks out.
# (the top two can be argued, but, i'll leave it there for now)

# %% [markdown]
# ### 2: Description head

# %%
# might need to install these libraries first
import enchant   
import nltk
from nltk.stem import PorterStemmer
nltk.download('stopwords')
from nltk.corpus import stopwords

def preprocess_text(text):
    # preprocesses a string of texts :)
    
    # remove non-alphabetic characters
    text = re.sub(r'[^a-z\sA-Z]', ' ', text)
    # convert all spacing characters such as tabs and newlines to 
    # whitespace and ensure that only one whitespace character exists between each word
    text = re.sub(r'\s+', ' ', text)
    # Change all uppercase characters to lower case
    text = text.lower()
    # tokenise into words
    words = text.split()
    # remove invalid English words, stopwords, and single-letter words, and then stemming.
    # the valid word detector will unfortunately not be able to pick up words whose spelling 
    # are shortened (e.g., bedroom is written as bdrm), nor typos.
    d = enchant.Dict('en')
    ps = PorterStemmer()
    words = [ps.stem(i) for i in words \
        if (d.check(i) == True) and (len(i) > 1) and (i not in stopwords.words("english"))]
    return words
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/sesshah/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
df3 = df.copy()

for i in range(df3.shape[0]):
    # just to see progress
    if (i % 2000) == 0:
        print(i)
        
    # text preprocessing
    words = preprocess_text(df3.iat[i, 7])
    sentence = ' '.join([i for i in words])
    df3.iat[i, 7] = sentence
# Out:
# 0
# 2000
# 4000
# 6000
# 8000
# 10000

# %%
df3.head(3)
# Out:
#                                                                                                  name  \
# https://www.domain.com.au/3502-14-16-the-esplan...         3502/14-16 The Esplanade St Kilda VIC 3182
# https://www.domain.com.au/4203-35-spring-street...           4203/35 Spring Street Melbourne VIC 3000
# https://www.domain.com.au/901-902-85-market-str...  901 & 902/85 Market Street South Melbourne VIC...
#
#                                                    cost_text  \
# https://www.domain.com.au/3502-14-16-the-esplan...      5000
# https://www.domain.com.au/4203-35-spring-street...      4500
# https://www.domain.com.au/901-902-85-market-str...    3750.0
#
#                                                                    coordinates  \
# https://www.domain.com.au/3502-14-16-the-esplan...  [-37.8650177, 144.9746821]
# https://www.domain.com.au/4203-35-spring-street...  [-37.8141725, 144.9740049]
# https://www.domain.com.au/901-902-85-market-str...  [-37.8301164, 144.9569041]
#
#                                                    Bed Bath Park  \
# https://www.domain.com.au/3502-14-16-the-esplan...   1    1    1
# https://www.domain.com.au/4203-35-spring-street...   3    2    2
# https://www.domain.com.au/901-902-85-market-str...   2    2    1
#
#                                                               property_type  \
# https://www.domain.com.au/3502-14-16-the-esplan...  Apartment / Unit / Flat
# https://www.domain.com.au/4203-35-spring-street...  Apartment / Unit / Flat
# https://www.domain.com.au/901-902-85-market-str...  Apartment / Unit / Flat
#
#                                                                                             desc_head  \
# https://www.domain.com.au/3502-14-16-the-esplan...                                    noth els compar
# https://www.domain.com.au/4203-35-spring-street...                            arguabl captiv penthous
# https://www.domain.com.au/901-902-85-market-str...  call exclus penthous short stay minimum week stay
#
#                                                                                                  desc  \
# https://www.domain.com.au/3502-14-16-the-esplan...  Inspired by the interplay of timeless design a...
# https://www.domain.com.au/4203-35-spring-street...  Possibly the most prestigious CBD address in t...
# https://www.domain.com.au/901-902-85-market-str...   class="css-dxogle">* Unverified feature<svg a...
#
#                                                                                   additional features  \
# https://www.domain.com.au/3502-14-16-the-esplan...  [INSIDE:, Gym, Intercom, Study, Floorboards, B...
# https://www.domain.com.au/4203-35-spring-street...                                                 []
# https://www.domain.com.au/901-902-85-market-str...             [Dishwasher, Balcony / Deck, Intercom]
#
#                                                    internal_area_sqkm  \
# https://www.domain.com.au/3502-14-16-the-esplan...                 []
# https://www.domain.com.au/4203-35-spring-street...                 []
# https://www.domain.com.au/901-902-85-market-str...                 []
#
#                                                    land_area_sqkm
# https://www.domain.com.au/3502-14-16-the-esplan...             []
# https://www.domain.com.au/4203-35-spring-street...             []
# https://www.domain.com.au/901-902-85-market-str...             []

# %% [markdown]
# NOTE: TF-IDF should be applied after the train test split during the modelling phase, not now? At least, that's what they do in machine learning last sem, I will hold off from doing this until I'm absolutely sure about this.
#
# UPDATE: yes, it's ideally done after splitting

# %% [markdown]
# ### Final 3 features (they're gonna be dropped) + coordinates

# %%
# change coordinates into two columns of latitude and longitude
df4 = pd.concat([pd.DataFrame(df3['coordinates'].to_list()), df3.reset_index()], axis=1)
df4.drop("coordinates", axis=1, inplace=True)
df4.rename(columns={0:'latitude', 1:"longitude"}, inplace=True)

# drop other columns that are not needed
# desc, additional_features, and areas are too scarce to be useful, 
# and areas are directly correlated to the number of bed/bath/park so they might be redundant anyway,
# desc_head should do the job enough.
df4.drop("desc", axis=1, inplace=True)
df4.drop("additional features", axis=1, inplace=True)
df4.drop("internal_area_sqkm", axis=1, inplace=True)
df4.drop("land_area_sqkm", axis=1, inplace=True)

df4.head()
# Out:
#     latitude   longitude                                              index  \
# 0 -37.865018  144.974682  https://www.domain.com.au/3502-14-16-the-espla...
# 1 -37.814172  144.974005  https://www.domain.com.au/4203-35-spring-stree...
# 2 -37.830116  144.956904  https://www.domain.com.au/901-902-85-market-st...
# 3 -37.831081  145.052094  https://www.domain.com.au/hawthorn-east-vic-31...
# 4 -37.822397  144.938237  https://www.domain.com.au/50-south-wharf-drive...
#
#                                                 name cost_text Bed Bath Park  \
# 0         3502/14-16 The Esplanade St Kilda VIC 3182      5000   1    1    1
# 1           4203/35 Spring Street Melbourne VIC 3000      4500   3    2    2
# 2  901 & 902/85 Market Street South Melbourne VIC...    3750.0   2    2    1
# 3                             Hawthorn East VIC 3123      3750   4    2    3
# 4            50 South Wharf Drive Docklands VIC 3008      3750   2    2    1
#
#              property_type                                          desc_head
# 0  Apartment / Unit / Flat                                    noth els compar
# 1  Apartment / Unit / Flat                            arguabl captiv penthous
# 2  Apartment / Unit / Flat  call exclus penthous short stay minimum week stay
# 3                    House  luxuri finest month leas avail unfurnish fulli...
# 4                Townhouse                                 luxuri style space

# %%
# save to csv
filename = "../data/raw/full_property_data.csv"
df4.to_csv(filename)
